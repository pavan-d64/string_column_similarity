# %%
def compare_str_column(table3, table4):
    """
    This module is used for comparing every column of one table with every column of another table 
    we need this to match strings and standardize data 
    dependancies= pandas==1.4.4
                  fuzzywuzzy==0.18.0
    example : compare_str_column("table1.xlsx","table2.xlsx")
    output: similarity in percentage and mean similarity in percentage is in df for all columns of table 1 vs all columns of table 2 
    """
    exceldata1 = pd.read_excel(table3)
    exceldata2 = pd.read_excel(table4)
    
    table1 = exceldata1.values.tolist()
    table2 = exceldata2.values.tolist()

    df = pd.DataFrame(columns=["String1", "String2", "Similarity"])
    for k in range(len(table1[0])):
        for l in range(len(table2[0])):
            mean_similarity = 0
            for i in range(len(table1)):
                for j in range(len(table2)):
                    similarity = fuzz.ratio(table1[i][k], table2[j][l])
                    mean_similarity += fuzz.ratio(table1[i][k], table2[j][l])
                mean_similarity /= (len(table1) * len(table2))
            df = df.append({"String1": table1[i][k], "String2": table2[j][l], "Similarity": similarity, "mean_similarity": mean_similarity}, ignore_index=True)
    return df

# %%
compare_str_column("table1.xlsx","table2.xlsx")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3348\2445270094.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"String1": table1[i][k], "String2": table2[j][l], "Similarity": similarity, "mean_similarity": mean_similarity}, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3348\2445270094.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"String1": table1[i][k], "String2": table2[j][l], "Similarity": similarity, "mean_similarity": mean_similarity}, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3348\2445270094.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"String1": table1[i][k], "String2": table2[j][l], "Similarity": similarity, "mean_similarity": mean_similarity}, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3348\2445270094.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"String1": table1[i][k], "String2": table2[j][l], "Similarity": similarity, "mean_similarity": mean_similarity}, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3348\2445270094.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"String1": table1[i][k], "String2": table2[j][l], "Similarity": similarity, "mean_similarity": mean_similarity}, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3348\2445270094.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"String1": table1[i][k], "String2": table2[j][l], "Similarity": similarity, "mean_similarity": mean_similarity}, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3348\2445270094.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"String1": table1[i][k], "String2": table2[j][l], "Similarity": similarity, "mean_similarity": mean_similarity}, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3348\2445270094.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"String1": table1[i][k], "String2": table2[j][l], "Similarity": similarity, "mean_similarity": mean_similarity}, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3348\2445270094.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"String1": table1[i][k], "String2": table2[j][l], "Similarity": similarity, "mean_similarity": mean_similarity}, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3348\2445270094.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"String1": table1[i][k], "String2": table2[j][l], "Similarity": similarity, "mean_similarity": mean_similarity}, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3348\2445270094.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"String1": table1[i][k], "String2": table2[j][l], "Similarity": similarity, "mean_similarity": mean_similarity}, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3348\2445270094.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"String1": table1[i][k], "String2": table2[j][l], "Similarity": similarity, "mean_similarity": mean_similarity}, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3348\2445270094.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"String1": table1[i][k], "String2": table2[j][l], "Similarity": similarity, "mean_similarity": mean_similarity}, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3348\2445270094.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"String1": table1[i][k], "String2": table2[j][l], "Similarity": similarity, "mean_similarity": mean_similarity}, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3348\2445270094.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"String1": table1[i][k], "String2": table2[j][l], "Similarity": similarity, "mean_similarity": mean_similarity}, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3348\2445270094.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"String1": table1[i][k], "String2": table2[j][l], "Similarity": similarity, "mean_similarity": mean_similarity}, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3348\2445270094.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"String1": table1[i][k], "String2": table2[j][l], "Similarity": similarity, "mean_similarity": mean_similarity}, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3348\2445270094.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"String1": table1[i][k], "String2": table2[j][l], "Similarity": similarity, "mean_similarity": mean_similarity}, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3348\2445270094.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"String1": table1[i][k], "String2": table2[j][l], "Similarity": similarity, "mean_similarity": mean_similarity}, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3348\2445270094.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"String1": table1[i][k], "String2": table2[j][l], "Similarity": similarity, "mean_similarity": mean_similarity}, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3348\2445270094.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"String1": table1[i][k], "String2": table2[j][l], "Similarity": similarity, "mean_similarity": mean_similarity}, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3348\2445270094.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"String1": table1[i][k], "String2": table2[j][l], "Similarity": similarity, "mean_similarity": mean_similarity}, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3348\2445270094.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"String1": table1[i][k], "String2": table2[j][l], "Similarity": similarity, "mean_similarity": mean_similarity}, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3348\2445270094.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"String1": table1[i][k], "String2": table2[j][l], "Similarity": similarity, "mean_similarity": mean_similarity}, ignore_index=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3348\2445270094.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"String1": table1[i][k], "String2": table2[j][l], "Similarity": similarity, "mean_similarity": mean_similarity}, ignore_index=True)
#    String1 String2 Similarity  mean_similarity
# 0      ccb     ccb        100        20.721536
# 1      ccb     ffd          0         0.000000
# 2      ccb     ijk          0         0.000000
# 3      ccb     lmo          0         0.000000
# 4      ccb     omn          0         0.000000
# 5      ffd     ccb          0         0.000000
# 6      ffd     ffd        100        20.721536
# 7      ffd     ijk          0         0.000000
# 8      ffd     lmo          0         0.000000
# 9      ffd     omn          0         0.000000
# 10     ijk     ccb          0         0.000000
# 11     ijk     ffd          0         0.000000
# 12     ijk     ijk        100        17.113855
# 13     ijk     lmo          0        11.111111
# 14     ijk     omn          0         0.000000
# 15     lmo     ccb          0         0.000000
# 16     lmo     ffd          0         0.000000
# 17     lmo     ijk          0         0.499314
# 18     lmo     lmo        100        20.721536
# 19     lmo     omn         33        20.617284
# 20     omn     ccb          0         0.000000
# 21     omn     ffd          0         0.000000
# 22     omn     ijk          0         0.000000
# 23     omn     lmo         33        12.529492
# 24     omn     omn        100        25.012346
